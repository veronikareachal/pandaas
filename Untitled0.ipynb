# %% [markdown]
# <a href="https://colab.research.google.com/github/veronikareachal/pandaas/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/environmental-protection-expenditure-account-2009-2022.csv')
data
# Out:
#      year              sector       class  \
# 0    2009  Central government       Total
# 1    2010  Central government       Total
# 2    2011  Central government       Total
# 3    2012  Central government       Total
# 4    2013  Central government       Total
# ..    ...                 ...         ...
# 487  2016    Local government  Wastewater
# 488  2017    Local government  Wastewater
# 489  2018    Local government  Wastewater
# 490  2019    Local government  Wastewater
# 491  2020    Local government  Wastewater
#
#                                  cfn_tle1                       cfn_tle2  \
# 0    Environmental protection expenditure  Final consumption expenditure
# 1    Environmental protection expenditure  Final consumption expenditure
# 2    Environmental protection expenditure  Final consumption expenditure
# 3    Environmental protection expenditure  Final consumption expenditure
# 4    Environmental protection expenditure  Final consumption expenditure
# ...

# %%
data.head()
# Out:
#    year              sector  class                              cfn_tle1  \
# 0  2009  Central government  Total  Environmental protection expenditure
# 1  2010  Central government  Total  Environmental protection expenditure
# 2  2011  Central government  Total  Environmental protection expenditure
# 3  2012  Central government  Total  Environmental protection expenditure
# 4  2013  Central government  Total  Environmental protection expenditure
#
#                         cfn_tle2       units magnitude  \
# 0  Final consumption expenditure  Proportion    Actual
# 1  Final consumption expenditure  Proportion    Actual
# 2  Final consumption expenditure  Proportion    Actual
# 3  Final consumption expenditure  Proportion    Actual
# 4  Final consumption expenditure  Proportion    Actual
#
#                    source  data_value flag
# 0  Environmental Accounts         1.2    F
# 1  Environmental Accounts         1.2    F
# 2  Environmental Accounts         1.1    F
# ...

# %%
data.tail()
# Out:
#      year            sector       class                              cfn_tle1  \
# 487  2016  Local government  Wastewater  Environmental protection expenditure
# 488  2017  Local government  Wastewater  Environmental protection expenditure
# 489  2018  Local government  Wastewater  Environmental protection expenditure
# 490  2019  Local government  Wastewater  Environmental protection expenditure
# 491  2020  Local government  Wastewater  Environmental protection expenditure
#
#                           cfn_tle2    units magnitude                  source  \
# 487  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
# 488  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
# 489  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
# 490  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
# 491  Gross fixed capital formation  Dollars  Millions  Environmental Accounts
#
#      data_value flag
# ...

# %%
data.sample()
# Out:
#      year            sector                  class  \
# 202  2019  Local government  Air and water quality
#
#                                  cfn_tle1                       cfn_tle2  \
# 202  Environmental protection expenditure  Gross fixed capital formation
#
#           units magnitude                  source  data_value flag
# 202  Proportion    Actual  Environmental Accounts         0.1    F

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        492 non-null    int64
#  1   sector      492 non-null    object
#  2   class       492 non-null    object
#  3   cfn_tle1    492 non-null    object
#  4   cfn_tle2    492 non-null    object
#  5   units       492 non-null    object
#  6   magnitude   492 non-null    object
#  7   source      492 non-null    object
#  8   data_value  492 non-null    float64
#  9   flag        492 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 38.6+ KB

# %%
data.describe()
# Out:
#               year    data_value
# count   492.000000    492.000000
# mean   2015.012195   3627.312195
# std       3.796753  11212.808490
# min    2009.000000      0.000000
# 25%    2012.000000      2.900000
# 50%    2015.000000     33.000000
# 75%    2018.000000    879.250000
# max    2022.000000  75659.000000

# %%
data.nunique()
# Out:
# year           14
# sector          3
# class           6
# cfn_tle1        2
# cfn_tle2        2
# units           2
# magnitude       2
# source          2
# data_value    336
# flag            3
# dtype: int64

# %%
data.isnull()
# Out:
#       year  sector  class  cfn_tle1  cfn_tle2  units  magnitude  source  \
# 0    False   False  False     False     False  False      False   False
# 1    False   False  False     False     False  False      False   False
# 2    False   False  False     False     False  False      False   False
# 3    False   False  False     False     False  False      False   False
# 4    False   False  False     False     False  False      False   False
# ..     ...     ...    ...       ...       ...    ...        ...     ...
# 487  False   False  False     False     False  False      False   False
# 488  False   False  False     False     False  False      False   False
# 489  False   False  False     False     False  False      False   False
# 490  False   False  False     False     False  False      False   False
# 491  False   False  False     False     False  False      False   False
#
#      data_value   flag
# 0         False  False
# 1         False  False
# 2         False  False
# ...

# %%
data.clip()
# Out:
#      year              sector       class  \
# 0    2009  Central government       Total
# 1    2010  Central government       Total
# 2    2011  Central government       Total
# 3    2012  Central government       Total
# 4    2013  Central government       Total
# ..    ...                 ...         ...
# 487  2016    Local government  Wastewater
# 488  2017    Local government  Wastewater
# 489  2018    Local government  Wastewater
# 490  2019    Local government  Wastewater
# 491  2020    Local government  Wastewater
#
#                                  cfn_tle1                       cfn_tle2  \
# 0    Environmental protection expenditure  Final consumption expenditure
# 1    Environmental protection expenditure  Final consumption expenditure
# 2    Environmental protection expenditure  Final consumption expenditure
# 3    Environmental protection expenditure  Final consumption expenditure
# 4    Environmental protection expenditure  Final consumption expenditure
# ...

# %%
data.plot()
# Out:
# <Axes: >
